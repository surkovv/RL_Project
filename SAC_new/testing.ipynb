# %%
import gymnasium as gym
from sac import SAC
import numpy as np
env_name = "Pendulum-v1"
env = gym.make(env_name)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])
agent = SAC(env, 
            env_name,
            state_dim,
             action_dim,
             batch_size=64,
             episodes=200,
             num_steps=300,
             scale=0.1, 
             max_actions=max_action, 
             alpha=0.3, 
             use_autotune=False)

returns, eval_rewards = agent.train_with_seed(seed = 48)
np.save("RSCALE\\eval_rewards_SAC_PEND_48_RSCALE_0P1.npy",np.array(list(eval_rewards.values())))
np.save("RSCALE\\eval_timesteps_SAC_PEND_48_RSCALE_0P1_good.npy",np.array(list(eval_rewards.keys())))
np.save("RSCALE\\train_rewards_SAC_PEND_48_RSCALE_0P1.npy",np.array(list(returns.values())))
np.save("RSCALE\\train_timeseps_SAC_PEND_48_RSCALE_0P1.npy",np.array(list(eval_rewards.keys())))
# Out:
# c:\Users\marcm\anaconda3\envs\RL\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\marcm\anaconda3\envs\RL\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Episode 0, Return: -1215.01, average time: nan
# Episode 1, Return: -1446.65, average time: 0.15
# Episode 2, Return: -1359.16, average time: 0.15
# Episode 3, Return: -1625.41, average time: 0.15
# Episode 4, Return: -1752.20, average time: 0.15
# Episode 4, Eval return: -1529.00
# Episode 5, Return: -1067.00, average time: 0.15
# Episode 6, Return: -1059.04, average time: 1.30
# Episode 7, Return: -1523.92, average time: 3.22
# Episode 8, Return: -1265.36, average time: 3.97
# Episode 9, Return: -1636.81, average time: 4.41
# Episode 9, Eval return: -1338.77
# Episode 10, Return: -1431.93, average time: 4.77
# ...

# %%
agent = SAC(env, 
            env_name,
            state_dim,
             action_dim,
             batch_size=64,
             episodes=200,
             num_steps=300,
             scale=10, 
             max_actions=max_action, 
             alpha=0.3, 
             use_autotune=False)

returns, eval_rewards = agent.train_with_seed(seed = 48)
np.save("RSCALE\\eval_rewards_SAC_PEND_48_RSCALE_10.npy",np.array(list(eval_rewards.values())))
np.save("RSCALE\\eval_timesteps_SAC_PEND_48_RSCALE_10_good.npy",np.array(list(eval_rewards.keys())))
np.save("RSCALE\\train_rewards_SAC_PEND_48_RSCALE_10.npy",np.array(list(returns.values())))
np.save("RSCALE\\train_timeseps_SAC_PEND_48_RSCALE_10.npy",np.array(list(eval_rewards.keys())))
# Out:
# Episode 0, Return: -1206.81, average time: nan
# Episode 1, Return: -1050.02, average time: 0.28
# Episode 2, Return: -890.45, average time: 0.29
# Episode 3, Return: -1302.41, average time: 0.29
# Episode 4, Return: -1448.98, average time: 0.31
# Episode 4, Eval return: -1347.02
# Episode 5, Return: -1257.78, average time: 0.33
# Episode 6, Return: -1187.24, average time: 2.19
# Episode 7, Return: -1587.60, average time: 3.50
# Episode 8, Return: -1456.64, average time: 4.66
# Episode 9, Return: -1790.84, average time: 5.51
# Episode 9, Eval return: -1529.75
# Episode 10, Return: -1597.58, average time: 6.21
# Episode 11, Return: -1515.73, average time: 6.78
# Episode 12, Return: -1445.68, average time: 7.23
# Episode 13, Return: -929.25, average time: 7.64
# Episode 14, Return: -1195.59, average time: 7.96
# Episode 14, Eval return: -1102.17
# Episode 15, Return: -1018.25, average time: 8.25
# Episode 16, Return: -1193.78, average time: 8.50
# ...

# %%
agent = SAC(env, 
            env_name,
            state_dim,
             action_dim,
             batch_size=64,
             episodes=200,
             num_steps=300,
             scale=3, 
             max_actions=max_action, 
             alpha=0.01, 
             use_autotune=False)

returns, eval_rewards = agent.train_with_seed(seed = 48)
np.save("ALPHA\\eval_rewards_SAC_PEND_48_ALPHA_0P01.npy",np.array(list(eval_rewards.values())))
np.save("ALPHA\\eval_timesteps_SAC_PEND_48_ALPHA_0P01_good.npy",np.array(list(eval_rewards.keys())))
np.save("ALPHA\\train_rewards_SAC_PEND_48_ALPHA_0P01.npy",np.array(list(returns.values())))
np.save("ALPHA\\train_timeseps_SAC_PEND_48_ALPHA_0P01.npy",np.array(list(eval_rewards.keys())))
# Out:
# Episode 0, Return: -1206.81, average time: nan
# Episode 1, Return: -1050.02, average time: 0.18
# Episode 2, Return: -890.45, average time: 0.19
# Episode 3, Return: -1302.41, average time: 0.19
# Episode 4, Return: -1448.98, average time: 0.18
# Episode 4, Eval return: -1347.02
# Episode 5, Return: -1358.66, average time: 0.19
# Episode 6, Return: -1449.03, average time: 1.73
# Episode 7, Return: -1755.48, average time: 2.79
# Episode 8, Return: -1655.27, average time: 3.53
# Episode 9, Return: -1759.10, average time: 4.17
# Episode 9, Eval return: -1549.46
# Episode 10, Return: -1679.01, average time: 4.73
# Episode 11, Return: -1694.29, average time: 5.22
# Episode 12, Return: -1603.65, average time: 5.58
# Episode 13, Return: -868.78, average time: 5.89
# Episode 14, Return: -1039.02, average time: 6.18
# Episode 14, Eval return: -1076.25
# Episode 15, Return: -1022.35, average time: 6.43
# Episode 16, Return: -970.59, average time: 6.66
# ...

# %%
import gymnasium as gym
from sac import SAC
import numpy as np
env_name = "Pendulum-v1"
env = gym.make(env_name)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])
agent = SAC(env, 
            env_name,
            state_dim,
             action_dim,
             batch_size=64,
             episodes=200,
             num_steps=300,
             scale=3, 
             max_actions=max_action, 
             alpha=0.9, 
             use_autotune=False)

returns, eval_rewards = agent.train_with_seed(seed = 48)
np.save("ALPHA\\eval_rewards_SAC_PEND_48_ALPHA_2.npy",np.array(list(eval_rewards.values())))
np.save("ALPHA\\eval_timesteps_SAC_PEND_48_ALPHA_2_good.npy",np.array(list(eval_rewards.keys())))
np.save("ALPHA\\train_rewards_SAC_PEND_48_ALPHA_2.npy",np.array(list(returns.values())))
np.save("ALPHA\\train_timeseps_SAC_PEND_48_ALPHA_2.npy",np.array(list(eval_rewards.keys())))
# Out:
# c:\Users\marcm\anaconda3\envs\RL\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\marcm\anaconda3\envs\RL\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Episode 0, Return: -1342.31, average time: nan
# Episode 1, Return: -1355.36, average time: 0.38
# Episode 2, Return: -1355.61, average time: 0.31
# Episode 3, Return: -1251.54, average time: 0.29
# Episode 4, Return: -1209.93, average time: 0.28
# Episode 4, Eval return: -1322.49
# Episode 5, Return: -1014.67, average time: 0.27
# Episode 6, Return: -1072.21, average time: 1.87
# Episode 7, Return: -1635.18, average time: 3.09
# Episode 8, Return: -1207.68, average time: 4.41
# Episode 9, Return: -1731.27, average time: 5.20
# Episode 9, Eval return: -1278.20
# Episode 10, Return: -1434.49, average time: 5.74
# ...

# %%
agent = SAC(env, 
            env_name,
            state_dim,
             action_dim,
             batch_size=32,
             episodes=200,
             num_steps=300,
             scale=3, 
             max_actions=max_action, 
             alpha=0.3, 
             use_autotune=False)

returns, eval_rewards = agent.train_with_seed(seed = 48)
np.save("BATCH\\eval_rewards_SAC_PEND_48_BATCH_32.npy",np.array(list(eval_rewards.values())))
np.save("BATCH\\eval_timesteps_SAC_PEND_48_BATCH_32_good.npy",np.array(list(eval_rewards.keys())))
np.save("BATCH\\train_rewards_SAC_PEND_48_BATCH_32.npy",np.array(list(returns.values())))
np.save("BATCH\\train_timeseps_SAC_PEND_48_BATCH_32.npy",np.array(list(eval_rewards.keys())))
# Out:
# Episode 0, Return: -1206.81, average time: nan
# Episode 1, Return: -1050.02, average time: 0.20
# Episode 2, Return: -890.45, average time: 0.19
# Episode 3, Return: -1302.41, average time: 0.18
# Episode 4, Return: -1448.98, average time: 0.18
# Episode 4, Eval return: -1347.02
# Episode 5, Return: -1105.71, average time: 0.17
# Episode 6, Return: -1067.73, average time: 1.38
# Episode 7, Return: -1668.21, average time: 2.30
# Episode 8, Return: -1592.09, average time: 3.03
# Episode 9, Return: -1828.31, average time: 3.57
# Episode 9, Eval return: -1489.28
# Episode 10, Return: -1592.53, average time: 4.09
# Episode 11, Return: -1567.36, average time: 4.53
# Episode 12, Return: -1517.09, average time: 4.81
# Episode 13, Return: -973.20, average time: 5.10
# Episode 14, Return: -1052.88, average time: 5.35
# Episode 14, Eval return: -1232.54
# Episode 15, Return: -1047.60, average time: 5.59
# Episode 16, Return: -1020.37, average time: 5.79
# ...

# %%
agent = SAC(env, 
            env_name,
            state_dim,
             action_dim,
             batch_size=256,
             episodes=200,
             num_steps=300,
             scale=3, 
             max_actions=max_action, 
             alpha=0.3, 
             use_autotune=False)

returns, eval_rewards = agent.train_with_seed(seed = 48)
np.save("BATCH\\eval_rewards_SAC_PEND_48_BATCH_256.npy",np.array(list(eval_rewards.values())))
np.save("BATCH\\eval_timesteps_SAC_PEND_48_BATCH_256_good.npy",np.array(list(eval_rewards.keys())))
np.save("BATCH\\train_rewards_SAC_PEND_48_BATCH_256.npy",np.array(list(returns.values())))
np.save("BATCH\\train_timeseps_SAC_PEND_48_BATCH_256.npy",np.array(list(eval_rewards.keys())))
# Out:
# Episode 0, Return: -1045.84, average time: nan
# Episode 1, Return: -967.36, average time: 0.17
# Episode 2, Return: -1018.10, average time: 0.17
# Episode 3, Return: -1080.20, average time: 0.17
# Episode 4, Return: -1327.91, average time: 0.16
# Episode 4, Eval return: -1129.36
# Episode 5, Return: -1189.37, average time: 0.16
# Episode 6, Return: -1321.18, average time: 1.92
# Episode 7, Return: -1717.13, average time: 3.10
# Episode 8, Return: -1410.67, average time: 4.11
# Episode 9, Return: -1642.66, average time: 5.02
# Episode 9, Eval return: -1283.49
# Episode 10, Return: -1404.37, average time: 5.64
# Episode 11, Return: -1433.46, average time: 6.21
# Episode 12, Return: -1798.27, average time: 6.68
# Episode 13, Return: -731.69, average time: 7.04
# Episode 14, Return: -1122.76, average time: 7.43
# Episode 14, Eval return: -1243.66
# Episode 15, Return: -1064.96, average time: 7.70
# Episode 16, Return: -1179.87, average time: 7.97
# ...

# %%
agent = SAC(env, 
            env_name,
            state_dim,
             action_dim,
             batch_size=64,
             episodes=200,
             num_steps=512,
             scale=3, 
             max_actions=max_action, 
             alpha=0.3, 
             use_autotune=False)

returns, eval_rewards = agent.train_with_seed(seed = 48)
np.save("STEPS\\eval_rewards_SAC_PEND_48_STEPS_512.npy",np.array(list(eval_rewards.values())))
np.save("STEPS\\eval_timesteps_SAC_PEND_48_STEPS_512_good.npy",np.array(list(eval_rewards.keys())))
np.save("STEPS\\train_rewards_SAC_PEND_48_STEPS_512.npy",np.array(list(returns.values())))
np.save("STEPS\\train_timeseps_SAC_PEND_48_STEPS_512.npy",np.array(list(eval_rewards.keys())))
# Out:
# Episode 0, Return: -1383.84, average time: nan
# Episode 1, Return: -1437.64, average time: 0.21
# Episode 2, Return: -1408.62, average time: 0.20
# Episode 3, Return: -1345.76, average time: 0.19
# Episode 4, Return: -1315.87, average time: 0.19
# Episode 4, Eval return: -1280.59
# Episode 5, Return: -1404.12, average time: 0.18
# Episode 6, Return: -1068.35, average time: 1.47
# Episode 7, Return: -1567.94, average time: 2.35
# Episode 8, Return: -1106.34, average time: 3.15
# Episode 9, Return: -1450.47, average time: 3.84
# Episode 9, Eval return: -1142.98
# Episode 10, Return: -1289.63, average time: 4.33
# Episode 11, Return: -1426.69, average time: 4.73
# Episode 12, Return: -1555.79, average time: 5.13
# Episode 13, Return: -913.41, average time: 5.42
# Episode 14, Return: -1031.27, average time: 5.67
# Episode 14, Eval return: -1213.12
# Episode 15, Return: -1035.53, average time: 5.90
# Episode 16, Return: -976.93, average time: 6.15
# ...

# %%
agent = SAC(env, 
            env_name,
            state_dim,
             action_dim,
             batch_size=64,
             episodes=200,
             num_steps=128,
             scale=3, 
             max_actions=max_action, 
             alpha=0.3, 
             use_autotune=False)

returns, eval_rewards = agent.train_with_seed(seed = 48)
np.save("STEPS\\eval_rewards_SAC_PEND_48_STEPS_128.npy",np.array(list(eval_rewards.values())))
np.save("STEPS\\eval_timesteps_SAC_PEND_48_STEPS_128_good.npy",np.array(list(eval_rewards.keys())))
np.save("STEPS\\train_rewards_SAC_PEND_48_STEPS_128.npy",np.array(list(returns.values())))
np.save("STEPS\\train_timeseps_SAC_PEND_48_STEPS_128.npy",np.array(list(eval_rewards.keys())))
# Out:
# Episode 0, Return: -721.46, average time: nan
# Episode 1, Return: -686.96, average time: 0.11
# Episode 2, Return: -611.30, average time: 0.11
# Episode 3, Return: -819.17, average time: 0.12
# Episode 4, Return: -946.08, average time: 0.12
# Episode 4, Eval return: -858.24
# Episode 5, Return: -705.83, average time: 0.12
# Episode 6, Return: -823.14, average time: 0.12
# Episode 7, Return: -992.86, average time: 0.12
# Episode 8, Return: -819.14, average time: 0.24
# Episode 9, Return: -1087.69, average time: 0.74
# Episode 9, Eval return: -930.40
# Episode 10, Return: -1072.91, average time: 1.14
# Episode 11, Return: -1147.88, average time: 1.50
# Episode 12, Return: -1198.36, average time: 1.83
# Episode 13, Return: -719.43, average time: 2.14
# Episode 14, Return: -674.45, average time: 2.41
# Episode 14, Eval return: -946.75
# Episode 15, Return: -654.08, average time: 2.62
# Episode 16, Return: -706.80, average time: 2.80
# Episode 17, Return: -629.47, average time: 2.97
# ...

# %%
agent = SAC(env, 
            env_name,
            state_dim,
             action_dim,
             batch_size=64,
             episodes=200,
             num_steps=128,
             scale=3, 
             max_actions=max_action, 
             alpha=0.3, 
             use_autotune=False)

returns, eval_rewards = agent.train_with_seed(seed = 42)
np.save("STEPS\\eval_rewards_SAC_PEND_42_STEPS_128.npy",np.array(list(eval_rewards.values())))
np.save("STEPS\\eval_timesteps_SAC_PEND_42_STEPS_128_good.npy",np.array(list(eval_rewards.keys())))
np.save("STEPS\\train_rewards_SAC_PEND_42_STEPS_128.npy",np.array(list(returns.values())))
np.save("STEPS\\train_timeseps_SAC_PEND_42_STEPS_128.npy",np.array(list(eval_rewards.keys())))
# Out:
# Episode 0, Return: -901.45, average time: nan
# Episode 1, Return: -964.69, average time: 0.11
# Episode 2, Return: -806.28, average time: 0.10
# Episode 3, Return: -913.41, average time: 0.10
# Episode 4, Return: -663.83, average time: 0.10
# Episode 4, Eval return: -713.14
# Episode 5, Return: -1041.57, average time: 0.10
# Episode 6, Return: -830.00, average time: 0.11
# Episode 7, Return: -528.17, average time: 0.11
# Episode 8, Return: -920.34, average time: 0.23
# Episode 9, Return: -856.29, average time: 0.72
# Episode 9, Eval return: -785.34
# Episode 10, Return: -857.24, average time: 1.08
# Episode 11, Return: -1033.24, average time: 1.44
# Episode 12, Return: -733.80, average time: 1.76
# Episode 13, Return: -815.21, average time: 2.06
# Episode 14, Return: -900.83, average time: 2.36
# Episode 14, Eval return: -786.74
# Episode 15, Return: -627.32, average time: 2.62
# Episode 16, Return: -628.03, average time: 2.86
# Episode 17, Return: -503.21, average time: 3.07
# ...

# %%
agent = SAC(env, 
            env_name,
            state_dim,
             action_dim,
             batch_size=64,
             episodes=200,
             num_steps=128,
             scale=3, 
             max_actions=max_action, 
             alpha=0.3, 
             use_autotune=False)

returns, eval_rewards = agent.train_with_seed(seed = 45)
np.save("STEPS\\eval_rewards_SAC_PEND_45_STEPS_128.npy",np.array(list(eval_rewards.values())))
np.save("STEPS\\eval_timesteps_SAC_PEND_45_STEPS_128_good.npy",np.array(list(eval_rewards.keys())))
np.save("STEPS\\train_rewards_SAC_PEND_45_STEPS_128.npy",np.array(list(returns.values())))
np.save("STEPS\\train_timeseps_SAC_PEND_45_STEPS_128.npy",np.array(list(eval_rewards.keys())))
# Out:
# Episode 0, Return: -911.60, average time: nan
# Episode 1, Return: -736.61, average time: 0.10
# Episode 2, Return: -936.34, average time: 0.09
# Episode 3, Return: -753.73, average time: 0.10
# Episode 4, Return: -818.43, average time: 0.10
# Episode 4, Eval return: -989.07
# Episode 5, Return: -854.94, average time: 0.10
# Episode 6, Return: -860.36, average time: 0.10
# Episode 7, Return: -799.10, average time: 0.10
# Episode 8, Return: -980.78, average time: 0.22
# Episode 9, Return: -886.87, average time: 0.74
# Episode 9, Eval return: -891.62
# Episode 10, Return: -833.50, average time: 1.10
# Episode 11, Return: -931.01, average time: 1.45
# Episode 12, Return: -1171.00, average time: 1.77
# Episode 13, Return: -870.51, average time: 2.05
# Episode 14, Return: -841.64, average time: 2.30
# Episode 14, Eval return: -757.13
# Episode 15, Return: -948.51, average time: 2.51
# Episode 16, Return: -718.28, average time: 2.68
# Episode 17, Return: -694.89, average time: 2.84
# ...

# %%
import gymnasium as gym
from sac import SAC
import numpy as np
env_name = "MountainCarContinuous-v0"
env = gym.make(env_name)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])
agent = SAC(env, 
            env_name,
            state_dim,
             action_dim,
             batch_size=64,
             episodes=200,
             num_steps=128,
             scale=3, 
             max_actions=max_action, 
             alpha=0.3, 
             use_autotune=False)

returns, eval_rewards = agent.train_with_seed(seed = 48)
np.save("MCC_EVAL\\eval_rewards_SAC_MCC_48_STEPS_128.npy",np.array(list(eval_rewards.values())))
np.save("MCC_EVAL\\eval_timesteps_SAC_MCC_48_STEPS_128_good.npy",np.array(list(eval_rewards.keys())))
np.save("MCC_TRAIN\\train_rewards_SAC_MCC_48_STEPS_128.npy",np.array(list(returns.values())))
np.save("MCC_TRAIN\\train_timeseps_SAC_MCC_48_STEPS_128.npy",np.array(list(eval_rewards.keys())))
# Out:
# c:\Users\marcm\anaconda3\envs\RL\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\marcm\anaconda3\envs\RL\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Episode 0, Return: -4.33, average time: nan
# Episode 1, Return: -6.36, average time: 0.11
# Episode 2, Return: -9.30, average time: 2.34
# Episode 3, Return: -5.00, average time: 3.10
# Episode 4, Return: -5.04, average time: 3.51
# Episode 4, Eval return: -3.29
# Episode 5, Return: -9.86, average time: 3.80
# Episode 6, Return: -6.66, average time: 4.03
# Episode 7, Return: -7.50, average time: 4.21
# Episode 8, Return: -9.95, average time: 4.34
# Episode 9, Return: -9.19, average time: 4.44
# Episode 9, Eval return: -3.17
# Episode 10, Return: -6.29, average time: 4.53
# Episode 11, Return: -10.14, average time: 4.60
# ...
